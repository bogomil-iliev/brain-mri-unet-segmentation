# %% [markdown]
# # 1. Data Preparation

# %% [markdown]
# **1.1. Download and Unzip the Dataset.**

# %%
#Validation of what GPU is connected to the notebook.
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Jan 12 18:35:53 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0              42W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#NOTE - the dataset can be downloaded onto your drive from: https://www.kaggle.com/datasets/awsaf49/brats20-dataset-training-validation
#Copying the zipped dataset into the local directory of Google Colab.
#NOTE - Change the dataset path and destination path with your own file path.
import zipfile
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/ML/BraTS2020.zip", 'r')
zip_ref.extractall("/content/drive/MyDrive/ML/BraTS2020")
zip_ref.close()

# %% [markdown]
# #2. Data Analysis

# %% [markdown]
# **2.1. Load and Analyse the Dataset.**

# %%
#Importing of needed librariries for data analysis.
import os
import cv2
import random
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps
import nibabel as nib
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers import Rescaling, RandomFlip, RandomRotation

# %%
TRAIN_DATASET_PATH = "/content/drive/MyDrive/ML/BraTS2020/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/"

# %%
#Before moving forward, we must correct a small error in the dataset. The segmentation file in "BraTS20_Training_355" folder has an incorrect name. Now we will rename it to keep the same name as others.
old_name = TRAIN_DATASET_PATH + "BraTS20_Training_355/W39_1998.09.19_Segm.nii"
new_name = TRAIN_DATASET_PATH + "BraTS20_Training_355/BraTS20_Training_355_seg.nii"

# renaming the file
try:
    os.rename(old_name, new_name)
    print("File has been re-named successfully!")
except:
    print("File is already renamed!")
# Out:
# File is already renamed!

# %%
# load .nii file as a numpy array and print its shape.
test_image_flair = nib.load(TRAIN_DATASET_PATH + "BraTS20_Training_355/BraTS20_Training_355_flair.nii").get_fdata()
print("Shape: ", test_image_flair.shape)
print("Dtype: ", test_image_flair.dtype)
# Out:
# Shape:  (240, 240, 155)
# Dtype:  float64

# %%
#Checking minimum and maximum Pixel values in the dataset.
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1854.603271484375

# %%
#Invoking the MinMaxScaler() function in order to rescale the pixel values.
scaler = MinMaxScaler()

# %%
# Scale the test_image_flair array and then reshape it back to its original dimensions.
# This ensures the data is normalised and standardised for model input without altering its spatial structure.
test_image_flair = scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)

# %%
# Confirming the pixel intensity values.
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1.0

# %%
# rescaling t1
test_image_t1 = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1.nii').get_fdata()
test_image_t1 = scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

# rescaling t1ce
test_image_t1ce = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1ce.nii').get_fdata()
test_image_t1ce = scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

# rescaling t2
test_image_t2 = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t2.nii').get_fdata()
test_image_t2 = scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

# we will not rescale the mask
test_image_seg = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_seg.nii').get_fdata()

# %%
# Visualising re-scalled and normalised samples from the different modalities.
slice = 95

print("Slice Number: " + str(slice))

plt.figure(figsize=(12, 8))

# T1
plt.subplot(2, 3, 1)
plt.imshow(test_image_t1[:,:,slice], cmap='gray')
plt.title('T1')

# T1ce
plt.subplot(2, 3, 2)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1ce')

# T2
plt.subplot(2, 3, 3)
plt.imshow(test_image_t2[:,:,slice], cmap='gray')
plt.title('T2')

# Flair
plt.subplot(2, 3, 4)
plt.imshow(test_image_flair[:,:,slice], cmap='gray')
plt.title('FLAIR')

# Mask
plt.subplot(2, 3, 5)
plt.imshow(test_image_seg[:,:,slice])
plt.title('Mask')
plt.show()
# Out:
# Slice Number: 95

# %%
#To better understand the data structure, let's examine the shape of a modality scan and a segmentation mask. Note that in this dataset, all modalities and their corresponding segmentation masks share the same dimensions.
# Modality shape
print("Modality: ", test_image_t1.shape)

# Segmentation shape
print("Segmentation: ", test_image_seg.shape)
# Out:
# Modality:  (240, 240, 155)
# Segmentation:  (240, 240, 155)

# %%
# Different planes visualisation
slice = 95

print("Slice number: " + str(slice))

plt.figure(figsize=(12, 8))

# Apply a 90° rotation with an automatic resizing, otherwise the display is less obvious to analyze
# T1 - Transverse View
plt.subplot(1, 3, 1)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1 - Transverse View')

# T1 - Frontal View
plt.subplot(1, 3, 2)
plt.imshow(rotate(test_image_t1ce[:,slice,:], 90, resize=True), cmap='gray')
plt.title('T1 - Frontal View')

# T1 - Sagittal View
plt.subplot(1, 3, 3)
plt.imshow(rotate(test_image_t1ce[slice,:,:], 90, resize=True), cmap='gray')
plt.title('T1 - Sagittal View')
plt.show()
# Out:
# Slice number: 95

# %%
# Visualisation of all slices in order to locate a slice that is showing an area of interest.
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)

# montage allows us to concatenate multiple images of the same size horizontally and vertically
plt.imshow(rotate(montage(test_image_t1ce[:,:,:]), 90, resize=True), cmap ='gray');

# %%
# Second visualisation of slices excluding the ones that consist of dark reagions outside of the skull.
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)
plt.imshow(rotate(montage(test_image_t1ce[50:-50,:,:]), 90, resize=True), cmap ='gray');

# %%
# Skip 50:-50 slices since there is not much to see
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)
plt.imshow(rotate(montage(test_image_seg[50:-50,:,:]), 90, resize=True), cmap ='gray');

# %%
# Examination of segmentations delivered by doctors.
# Plotting the segmantation
cmap = matplotlib.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = matplotlib.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

# plotting the 95th slice
plt.imshow(test_image_seg[:,:,95], cmap=cmap, norm=norm)
plt.colorbar()
plt.show()

# %%
# Isolation of class 0
seg_0 = test_image_seg.copy()
seg_0[seg_0 != 0] = np.nan

# Isolation of class 1
seg_1 = test_image_seg.copy()
seg_1[seg_1 != 1] = np.nan

# Isolation of class 2
seg_2 = test_image_seg.copy()
seg_2[seg_2 != 2] = np.nan

# Isolation of class 4
seg_4 = test_image_seg.copy()
seg_4[seg_4 != 4] = np.nan

# Define legend
class_names = ['class 0', 'class 1', 'class 2', 'class 4']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, ax = plt.subplots(1, 5, figsize=(20, 20))

ax[0].imshow(test_image_seg[:,:, slice], cmap=cmap, norm=norm)
ax[0].set_title('Original Segmentation')
ax[0].legend(handles=legend, loc='lower left')

ax[1].imshow(seg_0[:,:, slice], cmap=cmap, norm=norm)
ax[1].set_title('Not Tumor (class 0)')

ax[2].imshow(seg_1[:,:, slice], cmap=cmap, norm=norm)
ax[2].set_title('Non-Enhancing Tumor (class 1)')

ax[3].imshow(seg_2[:,:, slice], cmap=cmap, norm=norm)
ax[3].set_title('Edema (class 2)')

ax[4].imshow(seg_4[:,:, slice], cmap=cmap, norm=norm)
ax[4].set_title('Enhancing Tumor (class 4)')

plt.show()

# %% [markdown]
# # 3. Data Preparation

# %% [markdown]
# **3.1.Prepare the Datasplits**

# %%
# lists of directories with studies
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories);

train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2)
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
# Print data distribution (Train: 68%, Test: 12%, Val: 20%)
print(f"Train length: {len(train_ids)}")
print(f"Validation length: {len(val_ids)}")
print(f"Test length: {len(test_ids)}")
# Out:
# Train length: 250
# Validation length: 74
# Test length: 45

# %%
#Plot data distribution
plt.bar(["Train","Valid","Test"],
        [len(train_ids), len(val_ids), len(test_ids)],
        align='center',
        color=[ 'green','red', 'blue'],
        label=["Train", "Valid", "Test"]
       )

plt.legend()

plt.ylabel('Number of Images')
plt.title('Data Distribution')

plt.show()

# %% [markdown]
# **3.2. Prepare the DataGenerator Function**

# %%
# Define seg-areas
SEGMENT_CLASSES = {
    0 : 'NOT tumor',
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3
}

# Select Slices and Image Size
VOLUME_SLICES = 100
VOLUME_START_AT = 22 # first slice of volume that we will include
IMG_SIZE=128

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))


        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii');
            flair = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t1ce.nii');
            t1ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_seg.nii');
            seg = nib.load(data_path).get_fdata()

            for j in range(VOLUME_SLICES):
                 X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
                 X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

                 y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];

        # Generate masks
        y[y==4] = 3;
        mask = tf.one_hot(y, 4);
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE));
        return X/np.max(X), Y

    #Resets the generator and starts from the beginning
    def repeat(self):
        self.on_epoch_end()  # Resets the indexes
        return self

training_generator = DataGenerator(train_ids).repeat()
valid_generator = DataGenerator(val_ids).repeat()
test_generator = DataGenerator(test_ids)

# %%
# Define a function to display one slice and its segmentation
def display_slice_and_segmentation(flair, t1ce, segmentation):
    fig, axes = plt.subplots(1, 3, figsize=(10, 5))

    axes[0].imshow(flair, cmap='gray')
    axes[0].set_title('Flair')
    axes[0].axis('off')

    axes[1].imshow(t1ce, cmap='gray')
    axes[1].set_title('T1CE')
    axes[1].axis('off')

    axes[2].imshow(segmentation) # Displaying segmentation
    axes[2].set_title('Segmentation')
    axes[2].axis('off')

    plt.tight_layout()
    plt.show()


# Retrieve the batch from the training generator
X_batch, Y_batch = training_generator[8]

# Extract Flair, T1CE, and segmentation from the batch
flair_batch = X_batch[:, :, :, 0]
t1ce_batch = X_batch[:, :, :, 1]
segmentation_batch = np.argmax(Y_batch, axis=-1)  # Convert one-hot encoded to categorical

# Extract the 50th slice from Flair, T1CE, and segmentation
slice_index = 60  # Indexing starts from 0
slice_flair = flair_batch[slice_index]
slice_t1ce = t1ce_batch[slice_index]
slice_segmentation = segmentation_batch[slice_index]

# Display the 50th slice and its segmentation
display_slice_and_segmentation(slice_flair, slice_t1ce, slice_segmentation)

# %% [markdown]
# # 4. Define the Evaluation Metrics and Loss Function.

# %% [markdown]
# **4.1. Definition of Categorical Cross-entropy and Dice Coefficient Loss Functions.**

# %%
# dice loss as defined above for 4 classes
import tensorflow as tf #Import tensorflow
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = tf.keras.backend.flatten(y_true[:,:,:,i])
        y_pred_f = tf.keras.backend.flatten(y_pred[:,:,:,i])
        intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

# %%
# Define per class evaluation of dice coef
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true[:,:,:,1] * y_pred[:,:,:,1]))
    return (2. * intersection) / (tf.keras.backend.sum(tf.keras.backend.square(y_true[:,:,:,1])) + tf.keras.backend.sum(tf.keras.backend.square(y_pred[:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true[:,:,:,2] * y_pred[:,:,:,2]))
    return (2. * intersection) / (tf.keras.backend.sum(tf.keras.backend.square(y_true[:,:,:,2])) + tf.keras.backend.sum(tf.keras.backend.square(y_pred[:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true[:,:,:,3] * y_pred[:,:,:,3]))
    return (2. * intersection) / (tf.keras.backend.sum(tf.keras.backend.square(y_true[:,:,:,3])) + tf.keras.backend.sum(tf.keras.backend.square(y_pred[:,:,:,3])) + epsilon)

# %% [markdown]
# **4.2. Defining the Evaluation Metrics - Accuracy, IoU, Dice Coeff., Sensitivity, Precision, Specificity.**

# %%
# Computing Precision
def precision(y_true, y_pred):
    true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    predicted_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    return precision


# Computing Sensitivity
def sensitivity(y_true, y_pred):
    true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + tf.keras.backend.epsilon())


# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

# %% [markdown]
# # 5. Model Deinition

# %% [markdown]
# **5.1. Definition of a 2D U-net.**

# %%
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)


    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

# %% [markdown]
# **5.2. Building and Plotting the Model.**

# %%
#Building the model.
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

model = build_unet(input_layer, 'he_normal', 0.2)

model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing])

# %%
#Plot the model
plot_model(model,
           show_shapes = True,
           show_dtype=False,
           show_layer_names = True,
           rankdir = 'TB',
           expand_nested = False,
           dpi = 70)

# %% [markdown]
# **5.3. Set up Callbacks.**

# %%
callbacks = [
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                          patience=2, min_lr=0.000001, verbose=1),
    keras.callbacks.ModelCheckpoint(filepath = 'model_.{epoch:02d}-{val_loss:.6f}.weights.h5', monitor='val_loss',
                          verbose=1, save_best_only=True, save_weights_only = True),
    CSVLogger('training.log', separator=',', append=False)
]

# %% [markdown]
# #6. Train and Save the Model

# %% [markdown]
# **6.1. Fitting of the Model.**

# %%
K.clear_session()

history =  model.fit(training_generator,
                    epochs=100,
                    #steps_per_epoch=len(train_ids),
                    callbacks= callbacks,
                    validation_data = valid_generator
                    )
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9853 - dice_coef: 0.3678 - dice_coef_edema: 0.3610 - dice_coef_enhancing: 0.3085 - dice_coef_necrotic: 0.2229 - loss: 0.0498 - mean_io_u: 0.5129 - precision: 0.9905 - sensitivity: 0.9797 - specificity: 0.9967
# Epoch 1: val_loss improved from 0.04961 to 0.03950, saving model to model_.01-0.039495.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 118s 461ms/step - accuracy: 0.9853 - dice_coef: 0.3678 - dice_coef_edema: 0.3611 - dice_coef_enhancing: 0.3086 - dice_coef_necrotic: 0.2228 - loss: 0.0498 - mean_io_u: 0.5128 - precision: 0.9905 - sensitivity: 0.9797 - specificity: 0.9967 - val_accuracy: 0.9879 - val_dice_coef: 0.3963 - val_dice_coef_edema: 0.3880 - val_dice_coef_enhancing: 0.3541 - val_dice_coef_necrotic: 0.2086 - val_loss: 0.0395 - val_mean_io_u: 0.5000 - val_precision: 0.9907 - val_sensitivity: 0.9848 - val_specificity: 0.9968 - learning_rate: 2.0000e-04
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9877 - dice_coef: 0.4124 - dice_coef_edema: 0.4696 - dice_coef_enhancing: 0.4196 - dice_coef_necrotic: 0.2489 - loss: 0.0402 - mean_io_u: 0.5133 - precision: 0.9913 - sensitivity: 0.9838 - specificity: 0.9970
# Epoch 2: val_loss improved from 0.03950 to 0.03670, saving model to model_.02-0.036698.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 126s 498ms/step - accuracy: 0.9877 - dice_coef: 0.4124 - dice_coef_edema: 0.4696 - dice_coef_enhancing: 0.4195 - dice_coef_necrotic: 0.2489 - loss: 0.0402 - mean_io_u: 0.5133 - precision: 0.9913 - sensitivity: 0.9838 - specificity: 0.9970 - val_accuracy: 0.9886 - val_dice_coef: 0.4180 - val_dice_coef_edema: 0.4201 - val_dice_coef_enhancing: 0.4408 - val_dice_coef_necrotic: 0.2400 - val_loss: 0.0367 - val_mean_io_u: 0.5000 - val_precision: 0.9915 - val_sensitivity: 0.9852 - val_specificity: 0.9971 - learning_rate: 2.0000e-04
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9878 - dice_coef: 0.4210 - dice_coef_edema: 0.4841 - dice_coef_enhancing: 0.4202 - dice_coef_necrotic: 0.2452 - loss: 0.0395 - mean_io_u: 0.5114 - precision: 0.9909 - sensitivity: 0.9845 - specificity: 0.9969
# Epoch 3: val_loss improved from 0.03670 to 0.03183, saving model to model_.03-0.031826.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 127s 498ms/step - accuracy: 0.9878 - dice_coef: 0.4210 - dice_coef_edema: 0.4842 - dice_coef_enhancing: 0.4203 - dice_coef_necrotic: 0.2452 - loss: 0.0395 - mean_io_u: 0.5113 - precision: 0.9909 - sensitivity: 0.9845 - specificity: 0.9969 - val_accuracy: 0.9896 - val_dice_coef: 0.4523 - val_dice_coef_edema: 0.5515 - val_dice_coef_enhancing: 0.4565 - val_dice_coef_necrotic: 0.3215 - val_loss: 0.0318 - val_mean_io_u: 0.5000 - val_precision: 0.9925 - val_sensitivity: 0.9864 - val_specificity: 0.9974 - learning_rate: 2.0000e-04
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9888 - dice_coef: 0.4561 - dice_coef_edema: 0.5332 - dice_coef_enhancing: 0.4997 - dice_coef_necrotic: 0.3060 - loss: 0.0344 - mean_io_u: 0.5109 - precision: 0.9917 - sensitivity: 0.9855 - specificity: 0.9972
# Epoch 4: val_loss did not improve from 0.03183
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 128s 501ms/step - accuracy: 0.9888 - dice_coef: 0.4560 - dice_coef_edema: 0.5332 - dice_coef_enhancing: 0.4996 - dice_coef_necrotic: 0.3059 - loss: 0.0344 - mean_io_u: 0.5109 - precision: 0.9917 - sensitivity: 0.9855 - specificity: 0.9972 - val_accuracy: 0.9892 - val_dice_coef: 0.4419 - val_dice_coef_edema: 0.4765 - val_dice_coef_enhancing: 0.4615 - val_dice_coef_necrotic: 0.2559 - val_loss: 0.0340 - val_mean_io_u: 0.5000 - val_precision: 0.9912 - val_sensitivity: 0.9867 - val_specificity: 0.9970 - learning_rate: 2.0000e-04
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.9886 - dice_coef: 0.4671 - dice_coef_edema: 0.5577 - dice_coef_enhancing: 0.4991 - dice_coef_necrotic: 0.3363 - loss: 0.0330 - mean_io_u: 0.5125 - precision: 0.9917 - sensitivity: 0.9856 - specificity: 0.9971
# Epoch 5: val_loss improved from 0.03183 to 0.03037, saving model to model_.05-0.030367.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 125s 490ms/step - accuracy: 0.9886 - dice_coef: 0.4671 - dice_coef_edema: 0.5577 - dice_coef_enhancing: 0.4991 - dice_coef_necrotic: 0.3362 - loss: 0.0330 - mean_io_u: 0.5124 - precision: 0.9917 - sensitivity: 0.9856 - specificity: 0.9971 - val_accuracy: 0.9902 - val_dice_coef: 0.4739 - val_dice_coef_edema: 0.5573 - val_dice_coef_enhancing: 0.4977 - val_dice_coef_necrotic: 0.2673 - val_loss: 0.0304 - val_mean_io_u: 0.5000 - val_precision: 0.9918 - val_sensitivity: 0.9883 - val_specificity: 0.9972 - learning_rate: 2.0000e-04
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9892 - dice_coef: 0.4771 - dice_coef_edema: 0.5679 - dice_coef_enhancing: 0.5175 - dice_coef_necrotic: 0.3321 - loss: 0.0322 - mean_io_u: 0.5137 - precision: 0.9917 - sensitivity: 0.9864 - specificity: 0.9972
# Epoch 6: val_loss improved from 0.03037 to 0.02897, saving model to model_.06-0.028975.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 128s 504ms/step - accuracy: 0.9892 - dice_coef: 0.4771 - dice_coef_edema: 0.5679 - dice_coef_enhancing: 0.5176 - dice_coef_necrotic: 0.3321 - loss: 0.0322 - mean_io_u: 0.5136 - precision: 0.9917 - sensitivity: 0.9864 - specificity: 0.9972 - val_accuracy: 0.9906 - val_dice_coef: 0.4784 - val_dice_coef_edema: 0.5841 - val_dice_coef_enhancing: 0.5294 - val_dice_coef_necrotic: 0.2779 - val_loss: 0.0290 - val_mean_io_u: 0.5000 - val_precision: 0.9924 - val_sensitivity: 0.9884 - val_specificity: 0.9974 - learning_rate: 2.0000e-04
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9900 - dice_coef: 0.4806 - dice_coef_edema: 0.5952 - dice_coef_enhancing: 0.5143 - dice_coef_necrotic: 0.3420 - loss: 0.0294 - mean_io_u: 0.5044 - precision: 0.9922 - sensitivity: 0.9874 - specificity: 0.9973
# Epoch 7: val_loss improved from 0.02897 to 0.02666, saving model to model_.07-0.026658.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 127s 499ms/step - accuracy: 0.9900 - dice_coef: 0.4806 - dice_coef_edema: 0.5953 - dice_coef_enhancing: 0.5144 - dice_coef_necrotic: 0.3420 - loss: 0.0294 - mean_io_u: 0.5044 - precision: 0.9922 - sensitivity: 0.9874 - specificity: 0.9973 - val_accuracy: 0.9911 - val_dice_coef: 0.5086 - val_dice_coef_edema: 0.6569 - val_dice_coef_enhancing: 0.5578 - val_dice_coef_necrotic: 0.3501 - val_loss: 0.0267 - val_mean_io_u: 0.5000 - val_precision: 0.9927 - val_sensitivity: 0.9888 - val_specificity: 0.9975 - learning_rate: 2.0000e-04
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9905 - dice_coef: 0.4994 - dice_coef_edema: 0.6051 - dice_coef_enhancing: 0.5616 - dice_coef_necrotic: 0.3828 - loss: 0.0276 - mean_io_u: 0.5087 - precision: 0.9928 - sensitivity: 0.9877 - specificity: 0.9975
# Epoch 8: val_loss improved from 0.02666 to 0.02534, saving model to model_.08-0.025338.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 119s 471ms/step - accuracy: 0.9905 - dice_coef: 0.4994 - dice_coef_edema: 0.6052 - dice_coef_enhancing: 0.5617 - dice_coef_necrotic: 0.3829 - loss: 0.0276 - mean_io_u: 0.5086 - precision: 0.9928 - sensitivity: 0.9877 - specificity: 0.9975 - val_accuracy: 0.9916 - val_dice_coef: 0.5273 - val_dice_coef_edema: 0.6702 - val_dice_coef_enhancing: 0.5950 - val_dice_coef_necrotic: 0.4085 - val_loss: 0.0253 - val_mean_io_u: 0.5000 - val_precision: 0.9933 - val_sensitivity: 0.9890 - val_specificity: 0.9977 - learning_rate: 2.0000e-04
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9904 - dice_coef: 0.5232 - dice_coef_edema: 0.6455 - dice_coef_enhancing: 0.5828 - dice_coef_necrotic: 0.4060 - loss: 0.0270 - mean_io_u: 0.5153 - precision: 0.9927 - sensitivity: 0.9877 - specificity: 0.9975
# Epoch 9: val_loss did not improve from 0.02534
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 130s 510ms/step - accuracy: 0.9904 - dice_coef: 0.5232 - dice_coef_edema: 0.6454 - dice_coef_enhancing: 0.5828 - dice_coef_necrotic: 0.4060 - loss: 0.0270 - mean_io_u: 0.5152 - precision: 0.9927 - sensitivity: 0.9877 - specificity: 0.9975 - val_accuracy: 0.9913 - val_dice_coef: 0.5264 - val_dice_coef_edema: 0.6804 - val_dice_coef_enhancing: 0.5901 - val_dice_coef_necrotic: 0.3943 - val_loss: 0.0254 - val_mean_io_u: 0.5000 - val_precision: 0.9928 - val_sensitivity: 0.9891 - val_specificity: 0.9975 - learning_rate: 2.0000e-04
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9908 - dice_coef: 0.5370 - dice_coef_edema: 0.6582 - dice_coef_enhancing: 0.5865 - dice_coef_necrotic: 0.4665 - loss: 0.0261 - mean_io_u: 0.5090 - precision: 0.9927 - sensitivity: 0.9882 - specificity: 0.9975
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 10: val_loss improved from 0.02534 to 0.02527, saving model to model_.10-0.025269.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 122s 481ms/step - accuracy: 0.9908 - dice_coef: 0.5370 - dice_coef_edema: 0.6582 - dice_coef_enhancing: 0.5865 - dice_coef_necrotic: 0.4664 - loss: 0.0261 - mean_io_u: 0.5090 - precision: 0.9927 - sensitivity: 0.9882 - specificity: 0.9975 - val_accuracy: 0.9919 - val_dice_coef: 0.5375 - val_dice_coef_edema: 0.6691 - val_dice_coef_enhancing: 0.5780 - val_dice_coef_necrotic: 0.4118 - val_loss: 0.0253 - val_mean_io_u: 0.5000 - val_precision: 0.9933 - val_sensitivity: 0.9899 - val_specificity: 0.9977 - learning_rate: 2.0000e-04
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.9922 - dice_coef: 0.5572 - dice_coef_edema: 0.6872 - dice_coef_enhancing: 0.6350 - dice_coef_necrotic: 0.4810 - loss: 0.0221 - mean_io_u: 0.5140 - precision: 0.9938 - sensitivity: 0.9899 - specificity: 0.9979
# Epoch 11: val_loss improved from 0.02527 to 0.02297, saving model to model_.11-0.022974.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 124s 483ms/step - accuracy: 0.9922 - dice_coef: 0.5573 - dice_coef_edema: 0.6872 - dice_coef_enhancing: 0.6350 - dice_coef_necrotic: 0.4811 - loss: 0.0221 - mean_io_u: 0.5140 - precision: 0.9938 - sensitivity: 0.9899 - specificity: 0.9979 - val_accuracy: 0.9925 - val_dice_coef: 0.5594 - val_dice_coef_edema: 0.6974 - val_dice_coef_enhancing: 0.6150 - val_dice_coef_necrotic: 0.4677 - val_loss: 0.0230 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9904 - val_specificity: 0.9978 - learning_rate: 4.0000e-05
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9920 - dice_coef: 0.5724 - dice_coef_edema: 0.6731 - dice_coef_enhancing: 0.6454 - dice_coef_necrotic: 0.5371 - loss: 0.0225 - mean_io_u: 0.5142 - precision: 0.9935 - sensitivity: 0.9897 - specificity: 0.9978
# Epoch 12: val_loss did not improve from 0.02297
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 124s 491ms/step - accuracy: 0.9920 - dice_coef: 0.5724 - dice_coef_edema: 0.6732 - dice_coef_enhancing: 0.6454 - dice_coef_necrotic: 0.5371 - loss: 0.0225 - mean_io_u: 0.5141 - precision: 0.9935 - sensitivity: 0.9897 - specificity: 0.9978 - val_accuracy: 0.9924 - val_dice_coef: 0.5673 - val_dice_coef_edema: 0.7098 - val_dice_coef_enhancing: 0.6163 - val_dice_coef_necrotic: 0.4782 - val_loss: 0.0230 - val_mean_io_u: 0.5000 - val_precision: 0.9932 - val_sensitivity: 0.9906 - val_specificity: 0.9977 - learning_rate: 4.0000e-05
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9925 - dice_coef: 0.5784 - dice_coef_edema: 0.6997 - dice_coef_enhancing: 0.6393 - dice_coef_necrotic: 0.5277 - loss: 0.0208 - mean_io_u: 0.5143 - precision: 0.9938 - sensitivity: 0.9904 - specificity: 0.9979
# Epoch 13: val_loss improved from 0.02297 to 0.02263, saving model to model_.13-0.022634.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 122s 481ms/step - accuracy: 0.9925 - dice_coef: 0.5784 - dice_coef_edema: 0.6997 - dice_coef_enhancing: 0.6393 - dice_coef_necrotic: 0.5277 - loss: 0.0208 - mean_io_u: 0.5143 - precision: 0.9938 - sensitivity: 0.9904 - specificity: 0.9979 - val_accuracy: 0.9926 - val_dice_coef: 0.5710 - val_dice_coef_edema: 0.7105 - val_dice_coef_enhancing: 0.6192 - val_dice_coef_necrotic: 0.4567 - val_loss: 0.0226 - val_mean_io_u: 0.5000 - val_precision: 0.9934 - val_sensitivity: 0.9910 - val_specificity: 0.9978 - learning_rate: 4.0000e-05
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9924 - dice_coef: 0.5851 - dice_coef_edema: 0.7141 - dice_coef_enhancing: 0.6585 - dice_coef_necrotic: 0.5305 - loss: 0.0211 - mean_io_u: 0.5166 - precision: 0.9936 - sensitivity: 0.9903 - specificity: 0.9978
# Epoch 14: val_loss did not improve from 0.02263
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 122s 480ms/step - accuracy: 0.9924 - dice_coef: 0.5851 - dice_coef_edema: 0.7141 - dice_coef_enhancing: 0.6585 - dice_coef_necrotic: 0.5305 - loss: 0.0211 - mean_io_u: 0.5165 - precision: 0.9936 - sensitivity: 0.9903 - specificity: 0.9978 - val_accuracy: 0.9924 - val_dice_coef: 0.5669 - val_dice_coef_edema: 0.6925 - val_dice_coef_enhancing: 0.6417 - val_dice_coef_necrotic: 0.4837 - val_loss: 0.0228 - val_mean_io_u: 0.5000 - val_precision: 0.9938 - val_sensitivity: 0.9902 - val_specificity: 0.9979 - learning_rate: 4.0000e-05
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9931 - dice_coef: 0.5994 - dice_coef_edema: 0.7217 - dice_coef_enhancing: 0.6640 - dice_coef_necrotic: 0.5806 - loss: 0.0191 - mean_io_u: 0.5144 - precision: 0.9942 - sensitivity: 0.9912 - specificity: 0.9980
# Epoch 15: val_loss improved from 0.02263 to 0.02201, saving model to model_.15-0.022008.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 123s 486ms/step - accuracy: 0.9931 - dice_coef: 0.5994 - dice_coef_edema: 0.7217 - dice_coef_enhancing: 0.6639 - dice_coef_necrotic: 0.5805 - loss: 0.0191 - mean_io_u: 0.5143 - precision: 0.9942 - sensitivity: 0.9912 - specificity: 0.9980 - val_accuracy: 0.9927 - val_dice_coef: 0.5748 - val_dice_coef_edema: 0.7225 - val_dice_coef_enhancing: 0.6265 - val_dice_coef_necrotic: 0.4678 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9911 - val_specificity: 0.9978 - learning_rate: 4.0000e-05
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9929 - dice_coef: 0.5870 - dice_coef_edema: 0.7045 - dice_coef_enhancing: 0.6105 - dice_coef_necrotic: 0.5730 - loss: 0.0196 - mean_io_u: 0.5154 - precision: 0.9938 - sensitivity: 0.9910 - specificity: 0.9979
# Epoch 16: val_loss improved from 0.02201 to 0.02188, saving model to model_.16-0.021875.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 125s 491ms/step - accuracy: 0.9929 - dice_coef: 0.5871 - dice_coef_edema: 0.7046 - dice_coef_enhancing: 0.6107 - dice_coef_necrotic: 0.5729 - loss: 0.0196 - mean_io_u: 0.5153 - precision: 0.9938 - sensitivity: 0.9910 - specificity: 0.9979 - val_accuracy: 0.9929 - val_dice_coef: 0.5759 - val_dice_coef_edema: 0.7145 - val_dice_coef_enhancing: 0.6418 - val_dice_coef_necrotic: 0.4619 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9937 - val_sensitivity: 0.9912 - val_specificity: 0.9979 - learning_rate: 4.0000e-05
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9935 - dice_coef: 0.6073 - dice_coef_edema: 0.7302 - dice_coef_enhancing: 0.6766 - dice_coef_necrotic: 0.5826 - loss: 0.0181 - mean_io_u: 0.5169 - precision: 0.9944 - sensitivity: 0.9917 - specificity: 0.9981
# Epoch 17: val_loss did not improve from 0.02188
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 127s 501ms/step - accuracy: 0.9935 - dice_coef: 0.6073 - dice_coef_edema: 0.7302 - dice_coef_enhancing: 0.6765 - dice_coef_necrotic: 0.5825 - loss: 0.0181 - mean_io_u: 0.5169 - precision: 0.9944 - sensitivity: 0.9917 - specificity: 0.9981 - val_accuracy: 0.9928 - val_dice_coef: 0.5759 - val_dice_coef_edema: 0.7102 - val_dice_coef_enhancing: 0.6444 - val_dice_coef_necrotic: 0.4519 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9937 - val_sensitivity: 0.9911 - val_specificity: 0.9979 - learning_rate: 4.0000e-05
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9931 - dice_coef: 0.5864 - dice_coef_edema: 0.6934 - dice_coef_enhancing: 0.6356 - dice_coef_necrotic: 0.5662 - loss: 0.0189 - mean_io_u: 0.5173 - precision: 0.9942 - sensitivity: 0.9911 - specificity: 0.9980
# Epoch 18: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 18: val_loss did not improve from 0.02188
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 125s 490ms/step - accuracy: 0.9931 - dice_coef: 0.5864 - dice_coef_edema: 0.6936 - dice_coef_enhancing: 0.6357 - dice_coef_necrotic: 0.5662 - loss: 0.0189 - mean_io_u: 0.5173 - precision: 0.9942 - sensitivity: 0.9911 - specificity: 0.9980 - val_accuracy: 0.9927 - val_dice_coef: 0.5858 - val_dice_coef_edema: 0.7312 - val_dice_coef_enhancing: 0.6425 - val_dice_coef_necrotic: 0.4894 - val_loss: 0.0223 - val_mean_io_u: 0.5000 - val_precision: 0.9933 - val_sensitivity: 0.9912 - val_specificity: 0.9977 - learning_rate: 4.0000e-05
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9938 - dice_coef: 0.6139 - dice_coef_edema: 0.7467 - dice_coef_enhancing: 0.6926 - dice_coef_necrotic: 0.5776 - loss: 0.0174 - mean_io_u: 0.5151 - precision: 0.9945 - sensitivity: 0.9921 - specificity: 0.9981
# Epoch 19: val_loss did not improve from 0.02188
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 123s 487ms/step - accuracy: 0.9938 - dice_coef: 0.6139 - dice_coef_edema: 0.7467 - dice_coef_enhancing: 0.6925 - dice_coef_necrotic: 0.5777 - loss: 0.0174 - mean_io_u: 0.5150 - precision: 0.9945 - sensitivity: 0.9921 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5898 - val_dice_coef_edema: 0.7172 - val_dice_coef_enhancing: 0.6388 - val_dice_coef_necrotic: 0.4850 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 8.0000e-06
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9934 - dice_coef: 0.6017 - dice_coef_edema: 0.7190 - dice_coef_enhancing: 0.6594 - dice_coef_necrotic: 0.5654 - loss: 0.0181 - mean_io_u: 0.5180 - precision: 0.9943 - sensitivity: 0.9916 - specificity: 0.9980
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 20: val_loss did not improve from 0.02188
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 124s 486ms/step - accuracy: 0.9934 - dice_coef: 0.6017 - dice_coef_edema: 0.7191 - dice_coef_enhancing: 0.6595 - dice_coef_necrotic: 0.5655 - loss: 0.0181 - mean_io_u: 0.5179 - precision: 0.9943 - sensitivity: 0.9916 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5917 - val_dice_coef_edema: 0.7292 - val_dice_coef_enhancing: 0.6382 - val_dice_coef_necrotic: 0.4937 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 8.0000e-06
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9936 - dice_coef: 0.6019 - dice_coef_edema: 0.7379 - dice_coef_enhancing: 0.6402 - dice_coef_necrotic: 0.5719 - loss: 0.0176 - mean_io_u: 0.5172 - precision: 0.9942 - sensitivity: 0.9919 - specificity: 0.9980
# Epoch 21: val_loss improved from 0.02188 to 0.02181, saving model to model_.21-0.021809.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 132s 518ms/step - accuracy: 0.9936 - dice_coef: 0.6020 - dice_coef_edema: 0.7380 - dice_coef_enhancing: 0.6403 - dice_coef_necrotic: 0.5720 - loss: 0.0176 - mean_io_u: 0.5172 - precision: 0.9942 - sensitivity: 0.9919 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5918 - val_dice_coef_edema: 0.7254 - val_dice_coef_enhancing: 0.6433 - val_dice_coef_necrotic: 0.4960 - val_loss: 0.0218 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 1.6000e-06
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9937 - dice_coef: 0.6131 - dice_coef_edema: 0.7402 - dice_coef_enhancing: 0.6645 - dice_coef_necrotic: 0.5864 - loss: 0.0173 - mean_io_u: 0.5192 - precision: 0.9945 - sensitivity: 0.9919 - specificity: 0.9981
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 22: val_loss improved from 0.02181 to 0.02179, saving model to model_.22-0.021785.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 126s 491ms/step - accuracy: 0.9937 - dice_coef: 0.6132 - dice_coef_edema: 0.7403 - dice_coef_enhancing: 0.6645 - dice_coef_necrotic: 0.5864 - loss: 0.0173 - mean_io_u: 0.5191 - precision: 0.9945 - sensitivity: 0.9919 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5921 - val_dice_coef_edema: 0.7253 - val_dice_coef_enhancing: 0.6445 - val_dice_coef_necrotic: 0.4960 - val_loss: 0.0218 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 1.6000e-06
# Epoch 23/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9935 - dice_coef: 0.6185 - dice_coef_edema: 0.7277 - dice_coef_enhancing: 0.6690 - dice_coef_necrotic: 0.6132 - loss: 0.0180 - mean_io_u: 0.5187 - precision: 0.9943 - sensitivity: 0.9917 - specificity: 0.9980
# Epoch 23: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 118s 460ms/step - accuracy: 0.9935 - dice_coef: 0.6185 - dice_coef_edema: 0.7278 - dice_coef_enhancing: 0.6690 - dice_coef_necrotic: 0.6131 - loss: 0.0180 - mean_io_u: 0.5186 - precision: 0.9943 - sensitivity: 0.9917 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5923 - val_dice_coef_edema: 0.7246 - val_dice_coef_enhancing: 0.6443 - val_dice_coef_necrotic: 0.4962 - val_loss: 0.0218 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 24/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9935 - dice_coef: 0.6198 - dice_coef_edema: 0.7398 - dice_coef_enhancing: 0.6951 - dice_coef_necrotic: 0.5916 - loss: 0.0182 - mean_io_u: 0.5186 - precision: 0.9942 - sensitivity: 0.9917 - specificity: 0.9980
# Epoch 24: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 118s 462ms/step - accuracy: 0.9935 - dice_coef: 0.6198 - dice_coef_edema: 0.7398 - dice_coef_enhancing: 0.6950 - dice_coef_necrotic: 0.5916 - loss: 0.0182 - mean_io_u: 0.5185 - precision: 0.9942 - sensitivity: 0.9917 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5926 - val_dice_coef_edema: 0.7245 - val_dice_coef_enhancing: 0.6445 - val_dice_coef_necrotic: 0.4965 - val_loss: 0.0218 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 25/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9939 - dice_coef: 0.6097 - dice_coef_edema: 0.7355 - dice_coef_enhancing: 0.6681 - dice_coef_necrotic: 0.5707 - loss: 0.0170 - mean_io_u: 0.5189 - precision: 0.9945 - sensitivity: 0.9923 - specificity: 0.9981
# Epoch 25: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 127s 501ms/step - accuracy: 0.9939 - dice_coef: 0.6097 - dice_coef_edema: 0.7355 - dice_coef_enhancing: 0.6681 - dice_coef_necrotic: 0.5708 - loss: 0.0170 - mean_io_u: 0.5188 - precision: 0.9945 - sensitivity: 0.9923 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5927 - val_dice_coef_edema: 0.7237 - val_dice_coef_enhancing: 0.6442 - val_dice_coef_necrotic: 0.4959 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 26/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9936 - dice_coef: 0.6183 - dice_coef_edema: 0.7420 - dice_coef_enhancing: 0.6940 - dice_coef_necrotic: 0.5911 - loss: 0.0177 - mean_io_u: 0.5192 - precision: 0.9943 - sensitivity: 0.9917 - specificity: 0.9981
# Epoch 26: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 120s 470ms/step - accuracy: 0.9936 - dice_coef: 0.6183 - dice_coef_edema: 0.7420 - dice_coef_enhancing: 0.6939 - dice_coef_necrotic: 0.5911 - loss: 0.0177 - mean_io_u: 0.5191 - precision: 0.9943 - sensitivity: 0.9917 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5928 - val_dice_coef_edema: 0.7240 - val_dice_coef_enhancing: 0.6455 - val_dice_coef_necrotic: 0.4968 - val_loss: 0.0218 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 27/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9938 - dice_coef: 0.6214 - dice_coef_edema: 0.7481 - dice_coef_enhancing: 0.7018 - dice_coef_necrotic: 0.5859 - loss: 0.0168 - mean_io_u: 0.5194 - precision: 0.9946 - sensitivity: 0.9921 - specificity: 0.9981
# Epoch 27: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 127s 502ms/step - accuracy: 0.9938 - dice_coef: 0.6214 - dice_coef_edema: 0.7481 - dice_coef_enhancing: 0.7017 - dice_coef_necrotic: 0.5859 - loss: 0.0168 - mean_io_u: 0.5193 - precision: 0.9946 - sensitivity: 0.9921 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5929 - val_dice_coef_edema: 0.7253 - val_dice_coef_enhancing: 0.6457 - val_dice_coef_necrotic: 0.4984 - val_loss: 0.0218 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 28/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9938 - dice_coef: 0.6249 - dice_coef_edema: 0.7614 - dice_coef_enhancing: 0.6968 - dice_coef_necrotic: 0.5906 - loss: 0.0172 - mean_io_u: 0.5192 - precision: 0.9945 - sensitivity: 0.9920 - specificity: 0.9981
# Epoch 28: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 122s 477ms/step - accuracy: 0.9938 - dice_coef: 0.6249 - dice_coef_edema: 0.7613 - dice_coef_enhancing: 0.6968 - dice_coef_necrotic: 0.5906 - loss: 0.0172 - mean_io_u: 0.5192 - precision: 0.9945 - sensitivity: 0.9920 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5932 - val_dice_coef_edema: 0.7240 - val_dice_coef_enhancing: 0.6456 - val_dice_coef_necrotic: 0.4980 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 29/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9940 - dice_coef: 0.6206 - dice_coef_edema: 0.7528 - dice_coef_enhancing: 0.6817 - dice_coef_necrotic: 0.5920 - loss: 0.0168 - mean_io_u: 0.5187 - precision: 0.9946 - sensitivity: 0.9923 - specificity: 0.9981
# Epoch 29: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 122s 482ms/step - accuracy: 0.9940 - dice_coef: 0.6205 - dice_coef_edema: 0.7528 - dice_coef_enhancing: 0.6817 - dice_coef_necrotic: 0.5921 - loss: 0.0168 - mean_io_u: 0.5186 - precision: 0.9946 - sensitivity: 0.9923 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5935 - val_dice_coef_edema: 0.7258 - val_dice_coef_enhancing: 0.6444 - val_dice_coef_necrotic: 0.4967 - val_loss: 0.0218 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 30/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9941 - dice_coef: 0.6251 - dice_coef_edema: 0.7591 - dice_coef_enhancing: 0.6698 - dice_coef_necrotic: 0.6075 - loss: 0.0164 - mean_io_u: 0.5209 - precision: 0.9946 - sensitivity: 0.9924 - specificity: 0.9982
# Epoch 30: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 127s 503ms/step - accuracy: 0.9941 - dice_coef: 0.6250 - dice_coef_edema: 0.7590 - dice_coef_enhancing: 0.6698 - dice_coef_necrotic: 0.6075 - loss: 0.0164 - mean_io_u: 0.5208 - precision: 0.9946 - sensitivity: 0.9924 - specificity: 0.9982 - val_accuracy: 0.9930 - val_dice_coef: 0.5934 - val_dice_coef_edema: 0.7244 - val_dice_coef_enhancing: 0.6458 - val_dice_coef_necrotic: 0.4974 - val_loss: 0.0218 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 31/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9938 - dice_coef: 0.6201 - dice_coef_edema: 0.7516 - dice_coef_enhancing: 0.6798 - dice_coef_necrotic: 0.5955 - loss: 0.0173 - mean_io_u: 0.5192 - precision: 0.9945 - sensitivity: 0.9920 - specificity: 0.9981
# Epoch 31: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 124s 489ms/step - accuracy: 0.9938 - dice_coef: 0.6201 - dice_coef_edema: 0.7515 - dice_coef_enhancing: 0.6798 - dice_coef_necrotic: 0.5955 - loss: 0.0173 - mean_io_u: 0.5191 - precision: 0.9945 - sensitivity: 0.9920 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5936 - val_dice_coef_edema: 0.7246 - val_dice_coef_enhancing: 0.6457 - val_dice_coef_necrotic: 0.4980 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 32/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9934 - dice_coef: 0.6151 - dice_coef_edema: 0.7432 - dice_coef_enhancing: 0.6697 - dice_coef_necrotic: 0.5846 - loss: 0.0183 - mean_io_u: 0.5208 - precision: 0.9942 - sensitivity: 0.9915 - specificity: 0.9980
# Epoch 32: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 120s 475ms/step - accuracy: 0.9934 - dice_coef: 0.6151 - dice_coef_edema: 0.7433 - dice_coef_enhancing: 0.6698 - dice_coef_necrotic: 0.5847 - loss: 0.0183 - mean_io_u: 0.5207 - precision: 0.9942 - sensitivity: 0.9915 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5938 - val_dice_coef_edema: 0.7251 - val_dice_coef_enhancing: 0.6460 - val_dice_coef_necrotic: 0.4974 - val_loss: 0.0218 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 33/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9939 - dice_coef: 0.6088 - dice_coef_edema: 0.7511 - dice_coef_enhancing: 0.6115 - dice_coef_necrotic: 0.5956 - loss: 0.0169 - mean_io_u: 0.5194 - precision: 0.9945 - sensitivity: 0.9922 - specificity: 0.9981
# Epoch 33: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 130s 509ms/step - accuracy: 0.9939 - dice_coef: 0.6088 - dice_coef_edema: 0.7511 - dice_coef_enhancing: 0.6117 - dice_coef_necrotic: 0.5956 - loss: 0.0170 - mean_io_u: 0.5193 - precision: 0.9945 - sensitivity: 0.9922 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5938 - val_dice_coef_edema: 0.7259 - val_dice_coef_enhancing: 0.6469 - val_dice_coef_necrotic: 0.4992 - val_loss: 0.0218 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9915 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 34/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9939 - dice_coef: 0.6204 - dice_coef_edema: 0.7296 - dice_coef_enhancing: 0.6856 - dice_coef_necrotic: 0.6123 - loss: 0.0171 - mean_io_u: 0.5196 - precision: 0.9945 - sensitivity: 0.9922 - specificity: 0.9981
# Epoch 34: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 119s 470ms/step - accuracy: 0.9939 - dice_coef: 0.6204 - dice_coef_edema: 0.7296 - dice_coef_enhancing: 0.6856 - dice_coef_necrotic: 0.6123 - loss: 0.0171 - mean_io_u: 0.5195 - precision: 0.9945 - sensitivity: 0.9922 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5942 - val_dice_coef_edema: 0.7257 - val_dice_coef_enhancing: 0.6449 - val_dice_coef_necrotic: 0.4974 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 35/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9939 - dice_coef: 0.6158 - dice_coef_edema: 0.7406 - dice_coef_enhancing: 0.6847 - dice_coef_necrotic: 0.5861 - loss: 0.0171 - mean_io_u: 0.5180 - precision: 0.9946 - sensitivity: 0.9922 - specificity: 0.9981
# Epoch 35: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 118s 462ms/step - accuracy: 0.9939 - dice_coef: 0.6158 - dice_coef_edema: 0.7407 - dice_coef_enhancing: 0.6847 - dice_coef_necrotic: 0.5861 - loss: 0.0171 - mean_io_u: 0.5179 - precision: 0.9946 - sensitivity: 0.9922 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5943 - val_dice_coef_edema: 0.7256 - val_dice_coef_enhancing: 0.6455 - val_dice_coef_necrotic: 0.4974 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 36/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9933 - dice_coef: 0.6174 - dice_coef_edema: 0.7415 - dice_coef_enhancing: 0.6726 - dice_coef_necrotic: 0.5917 - loss: 0.0184 - mean_io_u: 0.5197 - precision: 0.9940 - sensitivity: 0.9915 - specificity: 0.9980
# Epoch 36: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 116s 456ms/step - accuracy: 0.9933 - dice_coef: 0.6174 - dice_coef_edema: 0.7416 - dice_coef_enhancing: 0.6726 - dice_coef_necrotic: 0.5917 - loss: 0.0184 - mean_io_u: 0.5196 - precision: 0.9940 - sensitivity: 0.9915 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5943 - val_dice_coef_edema: 0.7239 - val_dice_coef_enhancing: 0.6456 - val_dice_coef_necrotic: 0.4979 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9934 - dice_coef: 0.6118 - dice_coef_edema: 0.7419 - dice_coef_enhancing: 0.6676 - dice_coef_necrotic: 0.5795 - loss: 0.0181 - mean_io_u: 0.5202 - precision: 0.9941 - sensitivity: 0.9916 - specificity: 0.9980
# Epoch 37: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 121s 475ms/step - accuracy: 0.9934 - dice_coef: 0.6119 - dice_coef_edema: 0.7420 - dice_coef_enhancing: 0.6676 - dice_coef_necrotic: 0.5796 - loss: 0.0181 - mean_io_u: 0.5201 - precision: 0.9941 - sensitivity: 0.9916 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5943 - val_dice_coef_edema: 0.7258 - val_dice_coef_enhancing: 0.6466 - val_dice_coef_necrotic: 0.4986 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9936 - dice_coef: 0.6327 - dice_coef_edema: 0.7581 - dice_coef_enhancing: 0.6944 - dice_coef_necrotic: 0.6214 - loss: 0.0178 - mean_io_u: 0.5200 - precision: 0.9943 - sensitivity: 0.9917 - specificity: 0.9980
# Epoch 38: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 124s 488ms/step - accuracy: 0.9936 - dice_coef: 0.6327 - dice_coef_edema: 0.7581 - dice_coef_enhancing: 0.6944 - dice_coef_necrotic: 0.6213 - loss: 0.0178 - mean_io_u: 0.5199 - precision: 0.9943 - sensitivity: 0.9917 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5946 - val_dice_coef_edema: 0.7259 - val_dice_coef_enhancing: 0.6457 - val_dice_coef_necrotic: 0.4983 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9935 - dice_coef: 0.6127 - dice_coef_edema: 0.7388 - dice_coef_enhancing: 0.6760 - dice_coef_necrotic: 0.5785 - loss: 0.0180 - mean_io_u: 0.5200 - precision: 0.9943 - sensitivity: 0.9917 - specificity: 0.9980
# Epoch 39: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 123s 485ms/step - accuracy: 0.9935 - dice_coef: 0.6127 - dice_coef_edema: 0.7388 - dice_coef_enhancing: 0.6760 - dice_coef_necrotic: 0.5786 - loss: 0.0180 - mean_io_u: 0.5199 - precision: 0.9943 - sensitivity: 0.9917 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5947 - val_dice_coef_edema: 0.7265 - val_dice_coef_enhancing: 0.6467 - val_dice_coef_necrotic: 0.4997 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9934 - dice_coef: 0.6223 - dice_coef_edema: 0.7305 - dice_coef_enhancing: 0.6826 - dice_coef_necrotic: 0.6251 - loss: 0.0183 - mean_io_u: 0.5193 - precision: 0.9942 - sensitivity: 0.9916 - specificity: 0.9980
# Epoch 40: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 124s 487ms/step - accuracy: 0.9934 - dice_coef: 0.6223 - dice_coef_edema: 0.7305 - dice_coef_enhancing: 0.6826 - dice_coef_necrotic: 0.6250 - loss: 0.0183 - mean_io_u: 0.5192 - precision: 0.9942 - sensitivity: 0.9916 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5950 - val_dice_coef_edema: 0.7257 - val_dice_coef_enhancing: 0.6457 - val_dice_coef_necrotic: 0.4989 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9939 - dice_coef: 0.6213 - dice_coef_edema: 0.7594 - dice_coef_enhancing: 0.6987 - dice_coef_necrotic: 0.5817 - loss: 0.0170 - mean_io_u: 0.5186 - precision: 0.9945 - sensitivity: 0.9923 - specificity: 0.9981
# Epoch 41: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 115s 451ms/step - accuracy: 0.9939 - dice_coef: 0.6213 - dice_coef_edema: 0.7593 - dice_coef_enhancing: 0.6986 - dice_coef_necrotic: 0.5818 - loss: 0.0170 - mean_io_u: 0.5185 - precision: 0.9945 - sensitivity: 0.9923 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5949 - val_dice_coef_edema: 0.7244 - val_dice_coef_enhancing: 0.6470 - val_dice_coef_necrotic: 0.4988 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9932 - dice_coef: 0.6236 - dice_coef_edema: 0.7549 - dice_coef_enhancing: 0.6873 - dice_coef_necrotic: 0.6032 - loss: 0.0186 - mean_io_u: 0.5181 - precision: 0.9940 - sensitivity: 0.9913 - specificity: 0.9980
# Epoch 42: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 119s 461ms/step - accuracy: 0.9932 - dice_coef: 0.6236 - dice_coef_edema: 0.7548 - dice_coef_enhancing: 0.6873 - dice_coef_necrotic: 0.6032 - loss: 0.0186 - mean_io_u: 0.5181 - precision: 0.9940 - sensitivity: 0.9913 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5951 - val_dice_coef_edema: 0.7247 - val_dice_coef_enhancing: 0.6470 - val_dice_coef_necrotic: 0.4991 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9937 - dice_coef: 0.6051 - dice_coef_edema: 0.7216 - dice_coef_enhancing: 0.6349 - dice_coef_necrotic: 0.5944 - loss: 0.0174 - mean_io_u: 0.5185 - precision: 0.9943 - sensitivity: 0.9920 - specificity: 0.9981
# Epoch 43: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 122s 481ms/step - accuracy: 0.9937 - dice_coef: 0.6052 - dice_coef_edema: 0.7217 - dice_coef_enhancing: 0.6351 - dice_coef_necrotic: 0.5944 - loss: 0.0174 - mean_io_u: 0.5185 - precision: 0.9943 - sensitivity: 0.9920 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5952 - val_dice_coef_edema: 0.7246 - val_dice_coef_enhancing: 0.6467 - val_dice_coef_necrotic: 0.4986 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 44/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9937 - dice_coef: 0.6210 - dice_coef_edema: 0.7530 - dice_coef_enhancing: 0.6699 - dice_coef_necrotic: 0.6017 - loss: 0.0174 - mean_io_u: 0.5199 - precision: 0.9944 - sensitivity: 0.9920 - specificity: 0.9981
# Epoch 44: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 124s 490ms/step - accuracy: 0.9937 - dice_coef: 0.6210 - dice_coef_edema: 0.7529 - dice_coef_enhancing: 0.6699 - dice_coef_necrotic: 0.6016 - loss: 0.0174 - mean_io_u: 0.5198 - precision: 0.9944 - sensitivity: 0.9920 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5953 - val_dice_coef_edema: 0.7255 - val_dice_coef_enhancing: 0.6471 - val_dice_coef_necrotic: 0.4990 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9937 - dice_coef: 0.6290 - dice_coef_edema: 0.7543 - dice_coef_enhancing: 0.7011 - dice_coef_necrotic: 0.6162 - loss: 0.0174 - mean_io_u: 0.5193 - precision: 0.9944 - sensitivity: 0.9919 - specificity: 0.9981
# Epoch 45: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 120s 470ms/step - accuracy: 0.9937 - dice_coef: 0.6289 - dice_coef_edema: 0.7543 - dice_coef_enhancing: 0.7010 - dice_coef_necrotic: 0.6162 - loss: 0.0174 - mean_io_u: 0.5193 - precision: 0.9944 - sensitivity: 0.9919 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5954 - val_dice_coef_edema: 0.7252 - val_dice_coef_enhancing: 0.6477 - val_dice_coef_necrotic: 0.4998 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9937 - dice_coef: 0.6283 - dice_coef_edema: 0.7434 - dice_coef_enhancing: 0.7020 - dice_coef_necrotic: 0.6207 - loss: 0.0176 - mean_io_u: 0.5204 - precision: 0.9943 - sensitivity: 0.9919 - specificity: 0.9981
# Epoch 46: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 120s 473ms/step - accuracy: 0.9937 - dice_coef: 0.6283 - dice_coef_edema: 0.7434 - dice_coef_enhancing: 0.7019 - dice_coef_necrotic: 0.6207 - loss: 0.0176 - mean_io_u: 0.5203 - precision: 0.9943 - sensitivity: 0.9919 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5957 - val_dice_coef_edema: 0.7264 - val_dice_coef_enhancing: 0.6461 - val_dice_coef_necrotic: 0.4992 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9936 - dice_coef: 0.6196 - dice_coef_edema: 0.7621 - dice_coef_enhancing: 0.6723 - dice_coef_necrotic: 0.5798 - loss: 0.0173 - mean_io_u: 0.5193 - precision: 0.9943 - sensitivity: 0.9919 - specificity: 0.9981
# Epoch 47: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 124s 485ms/step - accuracy: 0.9936 - dice_coef: 0.6196 - dice_coef_edema: 0.7621 - dice_coef_enhancing: 0.6723 - dice_coef_necrotic: 0.5799 - loss: 0.0173 - mean_io_u: 0.5192 - precision: 0.9943 - sensitivity: 0.9919 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5957 - val_dice_coef_edema: 0.7264 - val_dice_coef_enhancing: 0.6476 - val_dice_coef_necrotic: 0.4995 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9940 - dice_coef: 0.6237 - dice_coef_edema: 0.7564 - dice_coef_enhancing: 0.6968 - dice_coef_necrotic: 0.5930 - loss: 0.0165 - mean_io_u: 0.5199 - precision: 0.9946 - sensitivity: 0.9923 - specificity: 0.9982
# Epoch 48: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 129s 510ms/step - accuracy: 0.9940 - dice_coef: 0.6237 - dice_coef_edema: 0.7564 - dice_coef_enhancing: 0.6967 - dice_coef_necrotic: 0.5930 - loss: 0.0165 - mean_io_u: 0.5198 - precision: 0.9946 - sensitivity: 0.9923 - specificity: 0.9982 - val_accuracy: 0.9930 - val_dice_coef: 0.5957 - val_dice_coef_edema: 0.7261 - val_dice_coef_enhancing: 0.6479 - val_dice_coef_necrotic: 0.5005 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 49/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.9934 - dice_coef: 0.6212 - dice_coef_edema: 0.7498 - dice_coef_enhancing: 0.6729 - dice_coef_necrotic: 0.6073 - loss: 0.0181 - mean_io_u: 0.5199 - precision: 0.9941 - sensitivity: 0.9915 - specificity: 0.9980
# Epoch 49: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 131s 516ms/step - accuracy: 0.9934 - dice_coef: 0.6212 - dice_coef_edema: 0.7498 - dice_coef_enhancing: 0.6729 - dice_coef_necrotic: 0.6073 - loss: 0.0181 - mean_io_u: 0.5198 - precision: 0.9941 - sensitivity: 0.9915 - specificity: 0.9980 - val_accuracy: 0.9930 - val_dice_coef: 0.5958 - val_dice_coef_edema: 0.7262 - val_dice_coef_enhancing: 0.6473 - val_dice_coef_necrotic: 0.5004 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 50/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9942 - dice_coef: 0.6075 - dice_coef_edema: 0.7531 - dice_coef_enhancing: 0.6817 - dice_coef_necrotic: 0.5427 - loss: 0.0162 - mean_io_u: 0.5205 - precision: 0.9948 - sensitivity: 0.9926 - specificity: 0.9982
# Epoch 50: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 119s 468ms/step - accuracy: 0.9942 - dice_coef: 0.6076 - dice_coef_edema: 0.7530 - dice_coef_enhancing: 0.6817 - dice_coef_necrotic: 0.5430 - loss: 0.0162 - mean_io_u: 0.5204 - precision: 0.9948 - sensitivity: 0.9926 - specificity: 0.9982 - val_accuracy: 0.9930 - val_dice_coef: 0.5960 - val_dice_coef_edema: 0.7262 - val_dice_coef_enhancing: 0.6472 - val_dice_coef_necrotic: 0.4997 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 51/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9941 - dice_coef: 0.6194 - dice_coef_edema: 0.7610 - dice_coef_enhancing: 0.6730 - dice_coef_necrotic: 0.5775 - loss: 0.0162 - mean_io_u: 0.5216 - precision: 0.9948 - sensitivity: 0.9924 - specificity: 0.9982
# Epoch 51: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 125s 491ms/step - accuracy: 0.9941 - dice_coef: 0.6194 - dice_coef_edema: 0.7609 - dice_coef_enhancing: 0.6730 - dice_coef_necrotic: 0.5776 - loss: 0.0162 - mean_io_u: 0.5215 - precision: 0.9948 - sensitivity: 0.9924 - specificity: 0.9982 - val_accuracy: 0.9930 - val_dice_coef: 0.5960 - val_dice_coef_edema: 0.7273 - val_dice_coef_enhancing: 0.6479 - val_dice_coef_necrotic: 0.5006 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 52/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.9932 - dice_coef: 0.6266 - dice_coef_edema: 0.7581 - dice_coef_enhancing: 0.6644 - dice_coef_necrotic: 0.6185 - loss: 0.0184 - mean_io_u: 0.5196 - precision: 0.9940 - sensitivity: 0.9914 - specificity: 0.9979
# Epoch 52: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 127s 502ms/step - accuracy: 0.9932 - dice_coef: 0.6265 - dice_coef_edema: 0.7580 - dice_coef_enhancing: 0.6645 - dice_coef_necrotic: 0.6184 - loss: 0.0184 - mean_io_u: 0.5195 - precision: 0.9940 - sensitivity: 0.9914 - specificity: 0.9979 - val_accuracy: 0.9930 - val_dice_coef: 0.5962 - val_dice_coef_edema: 0.7278 - val_dice_coef_enhancing: 0.6474 - val_dice_coef_necrotic: 0.4998 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 53/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9939 - dice_coef: 0.6299 - dice_coef_edema: 0.7534 - dice_coef_enhancing: 0.7091 - dice_coef_necrotic: 0.6043 - loss: 0.0170 - mean_io_u: 0.5204 - precision: 0.9945 - sensitivity: 0.9922 - specificity: 0.9981
# Epoch 53: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 115s 452ms/step - accuracy: 0.9939 - dice_coef: 0.6299 - dice_coef_edema: 0.7534 - dice_coef_enhancing: 0.7089 - dice_coef_necrotic: 0.6043 - loss: 0.0170 - mean_io_u: 0.5203 - precision: 0.9945 - sensitivity: 0.9922 - specificity: 0.9981 - val_accuracy: 0.9930 - val_dice_coef: 0.5962 - val_dice_coef_edema: 0.7254 - val_dice_coef_enhancing: 0.6475 - val_dice_coef_necrotic: 0.4990 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9916 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 54/100
# ...
# Epoch 83/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9937 - dice_coef: 0.6238 - dice_coef_edema: 0.7659 - dice_coef_enhancing: 0.6664 - dice_coef_necrotic: 0.5884 - loss: 0.0172 - mean_io_u: 0.5209 - precision: 0.9944 - sensitivity: 0.9919 - specificity: 0.9981
# Epoch 83: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 124s 486ms/step - accuracy: 0.9937 - dice_coef: 0.6238 - dice_coef_edema: 0.7659 - dice_coef_enhancing: 0.6665 - dice_coef_necrotic: 0.5885 - loss: 0.0172 - mean_io_u: 0.5208 - precision: 0.9944 - sensitivity: 0.9919 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.5990 - val_dice_coef_edema: 0.7280 - val_dice_coef_enhancing: 0.6496 - val_dice_coef_necrotic: 0.5022 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 84/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9938 - dice_coef: 0.6287 - dice_coef_edema: 0.7461 - dice_coef_enhancing: 0.6782 - dice_coef_necrotic: 0.6279 - loss: 0.0171 - mean_io_u: 0.5214 - precision: 0.9945 - sensitivity: 0.9921 - specificity: 0.9981
# Epoch 84: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 127s 501ms/step - accuracy: 0.9938 - dice_coef: 0.6287 - dice_coef_edema: 0.7461 - dice_coef_enhancing: 0.6783 - dice_coef_necrotic: 0.6278 - loss: 0.0171 - mean_io_u: 0.5213 - precision: 0.9945 - sensitivity: 0.9921 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.5991 - val_dice_coef_edema: 0.7288 - val_dice_coef_enhancing: 0.6495 - val_dice_coef_necrotic: 0.5025 - val_loss: 0.0219 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 85/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9940 - dice_coef: 0.6249 - dice_coef_edema: 0.7705 - dice_coef_enhancing: 0.6644 - dice_coef_necrotic: 0.5929 - loss: 0.0165 - mean_io_u: 0.5205 - precision: 0.9945 - sensitivity: 0.9924 - specificity: 0.9981
# Epoch 85: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 120s 474ms/step - accuracy: 0.9940 - dice_coef: 0.6249 - dice_coef_edema: 0.7705 - dice_coef_enhancing: 0.6645 - dice_coef_necrotic: 0.5930 - loss: 0.0165 - mean_io_u: 0.5204 - precision: 0.9945 - sensitivity: 0.9924 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.5993 - val_dice_coef_edema: 0.7291 - val_dice_coef_enhancing: 0.6486 - val_dice_coef_necrotic: 0.5016 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 86/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9933 - dice_coef: 0.6183 - dice_coef_edema: 0.7562 - dice_coef_enhancing: 0.6595 - dice_coef_necrotic: 0.5787 - loss: 0.0184 - mean_io_u: 0.5230 - precision: 0.9939 - sensitivity: 0.9915 - specificity: 0.9979
# Epoch 86: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 121s 476ms/step - accuracy: 0.9933 - dice_coef: 0.6183 - dice_coef_edema: 0.7562 - dice_coef_enhancing: 0.6596 - dice_coef_necrotic: 0.5789 - loss: 0.0184 - mean_io_u: 0.5229 - precision: 0.9939 - sensitivity: 0.9915 - specificity: 0.9979 - val_accuracy: 0.9931 - val_dice_coef: 0.5993 - val_dice_coef_edema: 0.7280 - val_dice_coef_enhancing: 0.6494 - val_dice_coef_necrotic: 0.5026 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 87/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9939 - dice_coef: 0.6159 - dice_coef_edema: 0.7461 - dice_coef_enhancing: 0.6703 - dice_coef_necrotic: 0.5758 - loss: 0.0168 - mean_io_u: 0.5224 - precision: 0.9945 - sensitivity: 0.9922 - specificity: 0.9981
# Epoch 87: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 121s 476ms/step - accuracy: 0.9939 - dice_coef: 0.6160 - dice_coef_edema: 0.7462 - dice_coef_enhancing: 0.6704 - dice_coef_necrotic: 0.5759 - loss: 0.0168 - mean_io_u: 0.5223 - precision: 0.9945 - sensitivity: 0.9922 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.5994 - val_dice_coef_edema: 0.7289 - val_dice_coef_enhancing: 0.6496 - val_dice_coef_necrotic: 0.5020 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 88/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.9939 - dice_coef: 0.6342 - dice_coef_edema: 0.7708 - dice_coef_enhancing: 0.7062 - dice_coef_necrotic: 0.6130 - loss: 0.0168 - mean_io_u: 0.5211 - precision: 0.9944 - sensitivity: 0.9922 - specificity: 0.9981
# Epoch 88: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 137s 541ms/step - accuracy: 0.9939 - dice_coef: 0.6342 - dice_coef_edema: 0.7708 - dice_coef_enhancing: 0.7062 - dice_coef_necrotic: 0.6130 - loss: 0.0168 - mean_io_u: 0.5210 - precision: 0.9944 - sensitivity: 0.9922 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.5994 - val_dice_coef_edema: 0.7289 - val_dice_coef_enhancing: 0.6502 - val_dice_coef_necrotic: 0.5028 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 89/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9944 - dice_coef: 0.6229 - dice_coef_edema: 0.7511 - dice_coef_enhancing: 0.6812 - dice_coef_necrotic: 0.5990 - loss: 0.0156 - mean_io_u: 0.5216 - precision: 0.9949 - sensitivity: 0.9929 - specificity: 0.9983
# Epoch 89: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 117s 462ms/step - accuracy: 0.9944 - dice_coef: 0.6229 - dice_coef_edema: 0.7511 - dice_coef_enhancing: 0.6812 - dice_coef_necrotic: 0.5990 - loss: 0.0156 - mean_io_u: 0.5215 - precision: 0.9949 - sensitivity: 0.9929 - specificity: 0.9983 - val_accuracy: 0.9931 - val_dice_coef: 0.5995 - val_dice_coef_edema: 0.7291 - val_dice_coef_enhancing: 0.6502 - val_dice_coef_necrotic: 0.5030 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 90/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9938 - dice_coef: 0.6296 - dice_coef_edema: 0.7646 - dice_coef_enhancing: 0.6816 - dice_coef_necrotic: 0.6099 - loss: 0.0169 - mean_io_u: 0.5219 - precision: 0.9944 - sensitivity: 0.9922 - specificity: 0.9981
# Epoch 90: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 122s 472ms/step - accuracy: 0.9938 - dice_coef: 0.6296 - dice_coef_edema: 0.7646 - dice_coef_enhancing: 0.6816 - dice_coef_necrotic: 0.6099 - loss: 0.0169 - mean_io_u: 0.5219 - precision: 0.9944 - sensitivity: 0.9922 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.5996 - val_dice_coef_edema: 0.7287 - val_dice_coef_enhancing: 0.6499 - val_dice_coef_necrotic: 0.5029 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9936 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 91/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9943 - dice_coef: 0.6373 - dice_coef_edema: 0.7710 - dice_coef_enhancing: 0.6895 - dice_coef_necrotic: 0.6407 - loss: 0.0156 - mean_io_u: 0.5216 - precision: 0.9948 - sensitivity: 0.9927 - specificity: 0.9982
# Epoch 91: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 126s 498ms/step - accuracy: 0.9943 - dice_coef: 0.6372 - dice_coef_edema: 0.7709 - dice_coef_enhancing: 0.6895 - dice_coef_necrotic: 0.6406 - loss: 0.0156 - mean_io_u: 0.5216 - precision: 0.9948 - sensitivity: 0.9927 - specificity: 0.9982 - val_accuracy: 0.9931 - val_dice_coef: 0.5999 - val_dice_coef_edema: 0.7285 - val_dice_coef_enhancing: 0.6492 - val_dice_coef_necrotic: 0.5015 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 92/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9939 - dice_coef: 0.6361 - dice_coef_edema: 0.7551 - dice_coef_enhancing: 0.7034 - dice_coef_necrotic: 0.6322 - loss: 0.0171 - mean_io_u: 0.5218 - precision: 0.9944 - sensitivity: 0.9921 - specificity: 0.9981
# Epoch 92: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 128s 503ms/step - accuracy: 0.9939 - dice_coef: 0.6361 - dice_coef_edema: 0.7551 - dice_coef_enhancing: 0.7034 - dice_coef_necrotic: 0.6322 - loss: 0.0171 - mean_io_u: 0.5217 - precision: 0.9944 - sensitivity: 0.9921 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.5998 - val_dice_coef_edema: 0.7282 - val_dice_coef_enhancing: 0.6489 - val_dice_coef_necrotic: 0.5011 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 93/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.9939 - dice_coef: 0.6343 - dice_coef_edema: 0.7626 - dice_coef_enhancing: 0.6827 - dice_coef_necrotic: 0.6320 - loss: 0.0169 - mean_io_u: 0.5227 - precision: 0.9945 - sensitivity: 0.9921 - specificity: 0.9981
# Epoch 93: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 125s 493ms/step - accuracy: 0.9939 - dice_coef: 0.6343 - dice_coef_edema: 0.7626 - dice_coef_enhancing: 0.6827 - dice_coef_necrotic: 0.6319 - loss: 0.0169 - mean_io_u: 0.5227 - precision: 0.9945 - sensitivity: 0.9921 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.5999 - val_dice_coef_edema: 0.7280 - val_dice_coef_enhancing: 0.6491 - val_dice_coef_necrotic: 0.5010 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 94/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9940 - dice_coef: 0.6337 - dice_coef_edema: 0.7632 - dice_coef_enhancing: 0.6967 - dice_coef_necrotic: 0.6054 - loss: 0.0163 - mean_io_u: 0.5215 - precision: 0.9945 - sensitivity: 0.9924 - specificity: 0.9981
# Epoch 94: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 123s 481ms/step - accuracy: 0.9940 - dice_coef: 0.6336 - dice_coef_edema: 0.7632 - dice_coef_enhancing: 0.6966 - dice_coef_necrotic: 0.6055 - loss: 0.0163 - mean_io_u: 0.5214 - precision: 0.9945 - sensitivity: 0.9924 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.6000 - val_dice_coef_edema: 0.7279 - val_dice_coef_enhancing: 0.6493 - val_dice_coef_necrotic: 0.5020 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 95/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9938 - dice_coef: 0.6286 - dice_coef_edema: 0.7669 - dice_coef_enhancing: 0.6876 - dice_coef_necrotic: 0.6004 - loss: 0.0170 - mean_io_u: 0.5220 - precision: 0.9944 - sensitivity: 0.9920 - specificity: 0.9981
# Epoch 95: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 119s 471ms/step - accuracy: 0.9938 - dice_coef: 0.6286 - dice_coef_edema: 0.7669 - dice_coef_enhancing: 0.6876 - dice_coef_necrotic: 0.6004 - loss: 0.0170 - mean_io_u: 0.5219 - precision: 0.9944 - sensitivity: 0.9920 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.6001 - val_dice_coef_edema: 0.7286 - val_dice_coef_enhancing: 0.6494 - val_dice_coef_necrotic: 0.5024 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 96/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9936 - dice_coef: 0.6342 - dice_coef_edema: 0.7586 - dice_coef_enhancing: 0.6869 - dice_coef_necrotic: 0.6244 - loss: 0.0175 - mean_io_u: 0.5217 - precision: 0.9941 - sensitivity: 0.9918 - specificity: 0.9980
# Epoch 96: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 123s 484ms/step - accuracy: 0.9936 - dice_coef: 0.6342 - dice_coef_edema: 0.7586 - dice_coef_enhancing: 0.6869 - dice_coef_necrotic: 0.6244 - loss: 0.0175 - mean_io_u: 0.5217 - precision: 0.9941 - sensitivity: 0.9918 - specificity: 0.9980 - val_accuracy: 0.9931 - val_dice_coef: 0.6002 - val_dice_coef_edema: 0.7277 - val_dice_coef_enhancing: 0.6495 - val_dice_coef_necrotic: 0.5019 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 97/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9941 - dice_coef: 0.6302 - dice_coef_edema: 0.7772 - dice_coef_enhancing: 0.6924 - dice_coef_necrotic: 0.5866 - loss: 0.0163 - mean_io_u: 0.5224 - precision: 0.9947 - sensitivity: 0.9924 - specificity: 0.9982
# Epoch 97: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 123s 482ms/step - accuracy: 0.9941 - dice_coef: 0.6302 - dice_coef_edema: 0.7771 - dice_coef_enhancing: 0.6923 - dice_coef_necrotic: 0.5867 - loss: 0.0163 - mean_io_u: 0.5223 - precision: 0.9947 - sensitivity: 0.9924 - specificity: 0.9982 - val_accuracy: 0.9931 - val_dice_coef: 0.6002 - val_dice_coef_edema: 0.7295 - val_dice_coef_enhancing: 0.6501 - val_dice_coef_necrotic: 0.5028 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 98/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.9936 - dice_coef: 0.6271 - dice_coef_edema: 0.7516 - dice_coef_enhancing: 0.7007 - dice_coef_necrotic: 0.6047 - loss: 0.0176 - mean_io_u: 0.5213 - precision: 0.9942 - sensitivity: 0.9918 - specificity: 0.9980
# Epoch 98: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 128s 504ms/step - accuracy: 0.9936 - dice_coef: 0.6271 - dice_coef_edema: 0.7517 - dice_coef_enhancing: 0.7006 - dice_coef_necrotic: 0.6047 - loss: 0.0176 - mean_io_u: 0.5212 - precision: 0.9942 - sensitivity: 0.9918 - specificity: 0.9980 - val_accuracy: 0.9931 - val_dice_coef: 0.6004 - val_dice_coef_edema: 0.7282 - val_dice_coef_enhancing: 0.6490 - val_dice_coef_necrotic: 0.5020 - val_loss: 0.0221 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 99/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9938 - dice_coef: 0.6284 - dice_coef_edema: 0.7534 - dice_coef_enhancing: 0.6760 - dice_coef_necrotic: 0.6116 - loss: 0.0170 - mean_io_u: 0.5226 - precision: 0.9944 - sensitivity: 0.9921 - specificity: 0.9981
# Epoch 99: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 114s 450ms/step - accuracy: 0.9938 - dice_coef: 0.6284 - dice_coef_edema: 0.7534 - dice_coef_enhancing: 0.6761 - dice_coef_necrotic: 0.6116 - loss: 0.0170 - mean_io_u: 0.5225 - precision: 0.9944 - sensitivity: 0.9921 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.6003 - val_dice_coef_edema: 0.7288 - val_dice_coef_enhancing: 0.6504 - val_dice_coef_necrotic: 0.5034 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06
# Epoch 100/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9937 - dice_coef: 0.6281 - dice_coef_edema: 0.7586 - dice_coef_enhancing: 0.6949 - dice_coef_necrotic: 0.5952 - loss: 0.0172 - mean_io_u: 0.5206 - precision: 0.9944 - sensitivity: 0.9919 - specificity: 0.9981
# Epoch 100: val_loss did not improve from 0.02179
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 120s 475ms/step - accuracy: 0.9937 - dice_coef: 0.6281 - dice_coef_edema: 0.7586 - dice_coef_enhancing: 0.6949 - dice_coef_necrotic: 0.5953 - loss: 0.0172 - mean_io_u: 0.5205 - precision: 0.9944 - sensitivity: 0.9919 - specificity: 0.9981 - val_accuracy: 0.9931 - val_dice_coef: 0.6004 - val_dice_coef_edema: 0.7288 - val_dice_coef_enhancing: 0.6497 - val_dice_coef_necrotic: 0.5025 - val_loss: 0.0220 - val_mean_io_u: 0.5000 - val_precision: 0.9935 - val_sensitivity: 0.9917 - val_specificity: 0.9978 - learning_rate: 1.0000e-06

# %% [markdown]
# **6.2. Save the trained model**

# %%
model.save("my_model_100.keras")

# %% [markdown]
# # 7. Load the Trained Model

# %%
model = keras.models.load_model('/content/my_model_100.keras',
                                   custom_objects={"accuracy" : tf.keras.metrics.MeanIoU(num_classes=4),
                                                   "dice_coef" : dice_coef,
                                                   "precision" : precision,
                                                   "sensitivity" :sensitivity,
                                                   "specificity" :specificity,
                                                   "dice_coef_necrotic" : dice_coef_necrotic,
                                                   "dice_coef_edema" : dice_coef_edema,
                                                   "dice_coef_enhancing" : dice_coef_enhancing
                                                  }, compile=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-1c2b458ed511> in <cell line: 1>()
# ----> 1 model = keras.models.load_model('/content/my_model_100.keras',
#       2                                    custom_objects={"accuracy" : tf.keras.metrics.MeanIoU(num_classes=4),
#       3                                                    "dice_coef" : dice_coef,
#       4                                                    "precision" : precision,
#       5                                                    "sensitivity" :sensitivity,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     196         )
#     197     elif str(filepath).endswith(".keras"):
# --> 198         raise ValueError(
#     199             f"File not found: filepath={filepath}. "
#     200             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=/content/my_model_100.keras. Please ensure the file is an accessible `.keras` zip file.

# %% [markdown]
# # 8. Metrics Analysis

# %% [markdown]
# **8.1. Plotting the Accuracy, Loss, Dice Coef., and IoU graphs.**

# %%
history = pd.read_csv('/content/training.log', sep=',', engine='python')

hist=history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u'],'r',label='Validation mean IOU')
ax[3].legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/python_parser.py in _next_iter_line(self, row_num)
#     804             assert self.data is not None
# --> 805             line = next(self.data)
#     806             # for mypy
#
# Error: line contains NUL
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-74-e0d390302c17> in <cell line: 1>()
# ----> 1 history = pd.read_csv('/content/training.log', sep=',', engine='python')
#       2
#       3 hist=history
#       4
#       5 acc=hist['accuracy']
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/python_parser.py in __init__(self, f, **kwds)
#     131             self.num_original_columns,
#     132             self.unnamed_cols,
# --> 133         ) = self._infer_columns()
#     134
#     135         # Now self.columns has the set of columns that we will process.
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/python_parser.py in _infer_columns(self)
#     402             for level, hr in enumerate(header):
#     403                 try:
# --> 404                     line = self._buffered_line()
#     405
#     406                     while self.line_pos <= hr:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/python_parser.py in _buffered_line(self)
#     635             return self.buf[0]
#     636         else:
# --> 637             return self._next_line()
#     638
#     639     def _check_for_bom(self, first_row: list[Scalar]) -> list[Scalar]:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/python_parser.py in _next_line(self)
#     736
#     737             while True:
# --> 738                 orig_line = self._next_iter_line(row_num=self.pos + 1)
#     739                 self.pos += 1
#     740
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/python_parser.py in _next_iter_line(self, row_num)
#     832                     msg += ". " + reason
#     833
# --> 834                 self._alert_malformed(msg, row_num)
#     835             return None
#     836
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/python_parser.py in _alert_malformed(self, msg, row_num)
#     779         """
#     780         if self.on_bad_lines == self.BadLineHandleMethod.ERROR:
# --> 781             raise ParserError(msg)
#     782         if self.on_bad_lines == self.BadLineHandleMethod.WARN:
#     783             warnings.warn(
#
# ParserError: NULL byte detected. This byte cannot be processed in Python's native csv library at the moment, so please pass in engine='c' instead

# %% [markdown]
# # 9. Make Predictions

# %%
# Compile a model and load our saved weights
import tensorflow as tf # Importing tensorflow here
IMG_SIZE = 128
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

best_saved_model = build_unet(input_layer, 'he_normal', 0.2)

best_saved_model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing])

best_saved_model.load_weights('my_model_100.keras')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 94 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
#Prediction Function
def imageLoader(path):
    image = nib.load(path).get_fdata()
    X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
    for j in range(VOLUME_SLICES):
        X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(image[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
        X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

        y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
    return np.array(image)

# %%
def loadDataFromDir(path, list_of_files, mriType, n_images):
    scans = []
    masks = []
    for i in list_of_files[:n_images]:
        fullPath = glob.glob( i + '/*'+ mriType +'*')[0]
        currentScanVolume = imageLoader(fullPath)
        currentMaskVolume = imageLoader( glob.glob( i + '/*seg*')[0] )
        # for each slice in 3D volume, find also it's mask
        for j in range(0, currentScanVolume.shape[2]):
            scan_img = cv2.resize(currentScanVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            mask_img = cv2.resize(currentMaskVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            scans.append(scan_img[..., np.newaxis])
            masks.append(mask_img[..., np.newaxis])
    return np.array(scans, dtype='float32'), np.array(masks, dtype='float32')

# %%
def predictByPath(case_path,case):
    files = next(os.walk(case_path))[2]
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii');
    flair=nib.load(vol_path).get_fdata()

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii');
    ce=nib.load(vol_path).get_fdata()


    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    return model.predict(X/np.max(X), verbose=1)

# %%
def showPredictsById(case, start_slice = 60):
    path = f"/content/drive/MyDrive/ML/BraTS2020/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
    gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
    origImage = nib.load(os.path.join(path, f'BraTS20_Training_{case}_flair.nii')).get_fdata()
    p = predictByPath(path,case)

    core = p[:,:,:,1]
    edema= p[:,:,:,2]
    enhancing = p[:,:,:,3]

    plt.figure(figsize=(18, 50))
    f, axarr = plt.subplots(1,6, figsize = (18, 50))

    for i in range(6): # for each image, add brain background
        axarr[i].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray", interpolation='none')

    axarr[0].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray")
    axarr[0].title.set_text('Original image flair')
    curr_gt=cv2.resize(gt[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    axarr[1].imshow(curr_gt, cmap="Reds", interpolation='none', alpha=0.3) # ,alpha=0.3,cmap='Reds'
    axarr[1].title.set_text('Ground truth')
    axarr[2].imshow(p[start_slice,:,:,1:4], cmap="Reds", interpolation='none', alpha=0.3)
    axarr[2].title.set_text('all classes predicted')
    axarr[3].imshow(edema[start_slice,:,:], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[3].title.set_text(f'{SEGMENT_CLASSES[1]} predicted')
    axarr[4].imshow(core[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[4].title.set_text(f'{SEGMENT_CLASSES[2]} predicted')
    axarr[5].imshow(enhancing[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[5].title.set_text(f'{SEGMENT_CLASSES[3]} predicted')
    plt.show()

# %%
showPredictsById(case=test_ids[0][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 610ms/step

# %%
showPredictsById(case=test_ids[1][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
showPredictsById(case=test_ids[2][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
showPredictsById(case=test_ids[3][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
showPredictsById(case=test_ids[4][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
showPredictsById(case=test_ids[5][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
showPredictsById(case=test_ids[6][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
def predict_segmentation(sample_path):
    # Load NIfTI (.nii) files of the sample (patient)
    t1ce_path = sample_path + '_t1ce.nii'
    flair_path = sample_path + '_flair.nii'

    # Extract the data from these paths
    t1ce = nib.load(t1ce_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()

    # Create an empty array
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    # Perform the same operations as our DataGenerator, to keep the same input shape
    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    # Send our images to the CNN model and return predicted segmentation
    return model.predict(X/np.max(X), verbose=1)

# %%
def show_predicted_segmentations(samples_list, slice_to_plot, cmap, norm):
    # Choose a random patient
    random_sample = random.choice(samples_list)

    # Get path of this patient
    random_sample_path = os.path.join(TRAIN_DATASET_PATH, random_sample, random_sample)

    # Predict patient's segmentation
    predicted_seg = predict_segmentation(random_sample_path)

    # Load patient's original segmentation (Ground truth)
    seg_path = random_sample_path + '_seg.nii'
    seg = nib.load(seg_path).get_fdata()

    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)

    # Differentiate segmentations by their labels
    all = predicted_seg[slice_to_plot,:,:,1:4] # Deletion of class 0 (Keep only Core + Edema + Enhancing classes)
    zero = predicted_seg[slice_to_plot,:,:,0] # Isolation of class 0, Background (kind of useless, it is the opposite of the "all")
    first = predicted_seg[slice_to_plot,:,:,1] # Isolation of class 1, Core
    second = predicted_seg[slice_to_plot,:,:,2] # Isolation of class 2, Edema
    third = predicted_seg[slice_to_plot,:,:,3] # Isolation of class 3, Enhancing

    # Plot Original segmentation & predicted segmentation
    print("Patient number: ", random_sample)
    fig, axstest = plt.subplots(1, 6, figsize=(25, 20))

    # Original segmentation
    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')

    # Layers 1, 2, 3
    axstest[1].imshow(all, cmap, norm)
    axstest[1].set_title('Predicted Segmentation - all classes')

    # Layer 0
    axstest[2].imshow(zero)
    axstest[2].set_title('Predicted Segmentation - Not Tumor')

    # Layer 1
    axstest[3].imshow(first)
    axstest[3].set_title('Predicted Segmentation - Necrotic/Core')

    # Layer 2
    axstest[4].imshow(second)
    axstest[4].set_title('Predicted Segmentation - Edema')

    # Layer 3
    axstest[5].imshow(third)
    axstest[5].set_title('Predicted Segmentation - Enhancing')

    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)

    plt.show()

# %%
show_predicted_segmentations(test_ids, 60, cmap, norm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step
# Patient number:  BraTS20_Training_257

# %%
show_predicted_segmentations(test_ids, 60, cmap, norm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Patient number:  BraTS20_Training_282

# %%
show_predicted_segmentations(test_ids, 65, cmap, norm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Patient number:  BraTS20_Training_051

# %%
case = test_ids[3][-3:]
path = f"/content/drive/MyDrive/ML/BraTS2020/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
p = predictByPath(path,case)

core = p[:,:,:,1]
edema= p[:,:,:,2]
enhancing = p[:,:,:,3]

i=40 # slice at
eval_class = 2 #     0 : 'NOT tumor',  1 : 'ENHANCING',    2 : 'CORE',    3 : 'WHOLE'

gt[gt != eval_class] = 1 # use only one class for per class evaluation

resized_gt = cv2.resize(gt[:,:,i+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

plt.figure()
f, axarr = plt.subplots(1,2)
axarr[0].imshow(resized_gt, cmap="gray")
axarr[0].title.set_text('ground truth')
axarr[1].imshow(p[i,:,:,eval_class], cmap="gray")
axarr[1].title.set_text(f'predicted class: {SEGMENT_CLASSES[eval_class]}')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# # 10. Evaluation

# %%
# Evaluate the model on the test data
model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing])

results = model.evaluate(test_generator, batch_size=100, callbacks= callbacks)

descriptions = ["Loss", "Accuracy", "MeanIOU", "Dice coefficient", "Precision", "Sensitivity", "Specificity", "Dice coef Necrotic", "Dice coef Edema", "Dice coef Enhancing"]

# Combine results list and descriptions list
results_list = zip(results, descriptions)

# Display each metric with its description
print("\nModel evaluation on the test set:")
print("==================================")
for i, (metric, description) in enumerate(results_list):
    print(f"{description} : {round(metric, 4)}")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9939 - dice_coef: 0.6131 - dice_coef_edema: 0.6869 - dice_coef_enhancing: 0.6559 - dice_coef_necrotic: 0.6390 - loss: 0.0189 - mean_io_u_4: 0.6148 - precision: 0.9944 - sensitivity: 0.9925 - specificity: 0.9981
#
# Model evaluation on the test set:
# ==================================
# Loss : 0.0259
# Accuracy : 0.993
# MeanIOU : 0.5
# Dice coefficient : 0.6098
# Precision : 0.9936
# Sensitivity : 0.9916
# Specificity : 0.9978
# Dice coef Necrotic : 0.6099
# Dice coef Edema : 0.686
# Dice coef Enhancing : 0.6524
